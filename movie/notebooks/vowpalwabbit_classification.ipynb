# %%
import pandas as pd
import sklearn as sk
import numpy as np

import vowpalwabbit as vw
from vowpalwabbit import pyvw

# %%
# %store -r pop

# %%
pop
# Out:
#                                 title  popularity  year  vote_average  \
# 30700                         Minions  547.488298  2015           6.4
# 33356                    Wonder Woman  294.337037  2017           7.2
# 42222            Beauty and the Beast  287.253654  2017           6.8
# 43644                     Baby Driver  228.032744  2017           7.2
# 24455                      Big Hero 6  213.849907  2014           7.8
# ...                               ...         ...   ...           ...
# 43962               Irwin & Fran 2013         NaN   NaT           NaN
# 44861           The End of a Vacation         NaN  1986           NaN
# 45070  The Garden of Afflictions 2017         NaN   NaT           NaN
# 45338  The Land Where the Blues Began         NaN   NaT           NaN
# 45432                   Altar of Fire         NaN  1976           NaN
#
#        vote_count
# 30700      4729.0
# 33356      5025.0
# 42222      5530.0
# 43644      2083.0
# 24455      6289.0
# ...
